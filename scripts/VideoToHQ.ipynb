# %%
# !wget https://mirror.clarkson.edu/blender/release/Blender3.6/blender-3.6.0-linux-x64.tar.xz
# !tar -xf blender-3.6.0-linux-x64.tar.xz
# Out:
# --2025-12-26 21:37:16--  https://mirror.clarkson.edu/blender/release/Blender3.6/blender-3.6.0-linux-x64.tar.xz
# Resolving mirror.clarkson.edu (mirror.clarkson.edu)... 128.153.145.19, 2605:6480:c051:100::1
# Connecting to mirror.clarkson.edu (mirror.clarkson.edu)|128.153.145.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 269076760 (257M) [application/octet-stream]
# Saving to: ‘blender-3.6.0-linux-x64.tar.xz’
#
# blender-3.6.0-linux 100%[===================>] 256.61M  5.98MB/s    in 53s
#
# 2025-12-26 21:38:10 (4.83 MB/s) - ‘blender-3.6.0-linux-x64.tar.xz’ saved [269076760/269076760]

# %%
# !pip install pillow

# %%
# !blender-3.6.0-linux-x64/blender --background --python blender_add_subtitles_and_export_frames.py
# Out:
# Blender 3.6.0 (hash c7fc78b81ecb built 2023-06-27 08:23:50)
# Saved: 'frames_legendados/frame_00000.png'
#  Time: 00:00.58 (Saving: 00:00.51)
#
# Saved: 'frames_legendados/frame_00144.png'
#  Time: 00:00.44 (Saving: 00:00.29)
#
# Saved: 'frames_legendados/frame_00288.png'
#  Time: 00:00.37 (Saving: 00:00.29)
#
# Saved: 'frames_legendados/frame_00624.png'
#  Time: 00:00.36 (Saving: 00:00.29)
#
# Saved: 'frames_legendados/frame_00816.png'
#  Time: 00:00.38 (Saving: 00:00.29)
#
# Saved: 'frames_legendados/frame_00960.png'
#  Time: 00:00.39 (Saving: 00:00.29)
#
# Saved: 'frames_legendados/frame_01104.png'
#  Time: 00:00.40 (Saving: 00:00.32)
#
# Saved: 'frames_legendados/frame_01272.png'
#  Time: 00:00.37 (Saving: 00:00.29)
#
# Saved: 'frames_legendados/frame_01392.png'
#  Time: 00:00.38 (Saving: 00:00.29)
#
# Saved: 'frames_legendados/frame_01560.png'
#  Time: 00:00.41 (Saving: 00:00.30)
#
# Saved: 'frames_legendados/frame_01728.png'
#  Time: 00:00.39 (Saving: 00:00.29)
#
# ...

# %%
import shutil
shutil.make_archive('frames_legendados', 'zip', 'frames_legendados')
# Out:
# '/content/frames_legendados.zip'

# %%
# !pip install pillow pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 91.4 MB/s eta 0:00:00
# ...

# %%
# !python frames_to_hq_pdf.py
# Out:
# PDF HQ gerado: hq_comic.pdf
